# %% [markdown]
# # Multilayer Perceptrons with scikit-learn
#
# **XBUS-512: Introduction to AI and Deep Learning**
#
# In this exercise, we will see how to build a preliminary neural model using the familiar scikit-learn library. While scikit-learn is not a deep learning library, it does provide basic implementations of the multilayer perceptron (MLP) for both classification and regression.
#
#
# Thanks to [this team](https://github.com/Wall-eSociety/CommentVolumeML) for figuring out the labels for this dataset!

# %% [markdown]
# ## Imports

# %%
import os
import zipfile
import requests
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split as tts
from sklearn.neural_network import MLPClassifier, MLPRegressor
from yellowbrick.regressor import PredictionError, ResidualsPlot

# %% [markdown]
# ## Download the data

# %%
def fetch_data(url, fname):
    """
    Helper method to retreive the data from the UCI ML Repository.
    """
    response = requests.get(url)
    outpath  = os.path.abspath(fname)
    with open(outpath, "wb") as f:
        f.write(response.content)
    
    return outpath

# %%
# Fetch and unzip the data

URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/00363/Dataset.zip"
ZIPPED_FILES = "facebook_data.zip"
UNZIPPED_FILES = "facebook_data"

zipped_data = fetch_data(URL, os.path.join("../fixtures", ZIPPED_FILES))

with zipfile.ZipFile(os.path.join("../fixtures", ZIPPED_FILES), "r") as zfiles:
    zfiles.extractall(os.path.join("../fixtures", UNZIPPED_FILES))

# %%
data = pd.read_csv(
    os.path.join(
        "../fixtures", 
        UNZIPPED_FILES, 
        "Dataset", 
        "Training", 
        "Features_Variant_2.csv"
    ),
    header=None
)
data.columns = [
    "likes", "views", "returns", "category", "derived_1", "derived_2", "derived_3",
    "derived_4", "derived_5", "derived_6", "derived_7", "derived_8", "derived_9",
    "derived_10", "derived_11", "derived_12", "derived_13", "derived_14", "derived_15", 
    "derived_16", "derived_17", "derived_18", "derived_19", "derived_20", "derived_21",
    "derived_22", "derived_23", "derived_24", "derived_25", "cc_1", "cc_2", "cc_3",
    "cc_4", "cc_5", "base_time", "length", "shares", "status", "h_local", "sunday_post",
    "monday_post", "tuesday_post", "wednesday_post", "thursday_post", "friday_post",
    "saturday_post", "sunday_base", "monday_base", "tuesday_base", "wednesday_base",
    "thursday_base", "friday_base", "saturday_base", "target"
]

data.describe()
# Out:
#               likes          views       returns      category     derived_1  \
# count  8.131200e+04   81312.000000  8.131200e+04  81312.000000  81312.000000
# mean   1.313921e+06    4667.704336  4.475377e+04     24.255633      0.707190
# std    6.804951e+06   20561.261034  1.109279e+05     19.949156     12.169748
# min    3.600000e+01       0.000000  0.000000e+00      1.000000      0.000000
# 25%    3.673400e+04       0.000000  6.980000e+02      9.000000      0.000000
# 50%    2.929110e+05       0.000000  7.045000e+03     18.000000      0.000000
# 75%    1.204214e+06      99.000000  5.026400e+04     32.000000      0.000000
# max    4.869723e+08  186370.000000  6.089942e+06    106.000000   1311.000000
#
#           derived_2     derived_3     derived_4     derived_5     derived_6  \
# count  81312.000000  81312.000000  81312.000000  81312.000000  81312.000000
# mean     464.665781     55.728933     35.392255     67.588653      0.143361
# std      520.925523     85.243275     67.043844     82.836764      7.819979
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       47.000000      5.190751      2.000000      8.032349      0.000000
# 50%      251.000000     22.794183     13.000000     32.565168      0.000000
# 75%      717.000000     71.791489     42.000000    102.060861      0.000000
# max     2438.000000   1693.500000   1693.500000    743.091650   1311.000000
#
#        ...   friday_post  saturday_post   sunday_base   monday_base  \
# count  ...  81312.000000   81312.000000  81312.000000  81312.000000
# mean   ...      0.146153       0.136954      0.141049      0.133400
# std    ...      0.353262       0.343801      0.348075      0.340008
# min    ...      0.000000       0.000000      0.000000      0.000000
# 25%    ...      0.000000       0.000000      0.000000      0.000000
# 50%    ...      0.000000       0.000000      0.000000      0.000000
# 75%    ...      0.000000       0.000000      0.000000      0.000000
# max    ...      1.000000       1.000000      1.000000      1.000000
#
#        tuesday_base  wednesday_base  thursday_base   friday_base  \
# count  81312.000000    81312.000000   81312.000000  81312.000000
# mean       0.138417        0.145477       0.155180      0.144997
# std        0.345340        0.352583       0.362078      0.352100
# min        0.000000        0.000000       0.000000      0.000000
# 25%        0.000000        0.000000       0.000000      0.000000
# 50%        0.000000        0.000000       0.000000      0.000000
# 75%        0.000000        0.000000       0.000000      0.000000
# max        1.000000        1.000000       1.000000      1.000000
#
#        saturday_base        target
# count   81312.000000  81312.000000
# mean        0.141480      7.190611
# std         0.348518     36.049374
# min         0.000000      0.000000
# 25%         0.000000      0.000000
# 50%         0.000000      0.000000
# 75%         0.000000      3.000000
# max         1.000000   1966.000000
#
# [8 rows x 54 columns]

# %%
def prepare_for_regression(dataframe):
    """
    Prepare the data for a regression problem where we will attempt
    to regress the number of comments that a Facebook post will get
    given other features of the data.
    
    Returns a tuple containing an nd array of features (X)
    and a 1d array for the target (y)
    """
    features = [
        "likes", "views", "returns", "category", "derived_1", "derived_2", "derived_3",
        "derived_4", "derived_5", "derived_6", "derived_7", "derived_8", "derived_9",
        "derived_10", "derived_11", "derived_12", "derived_13", "derived_14", "derived_15", 
        "derived_16", "derived_17", "derived_18", "derived_19", "derived_20", "derived_21",
        "derived_22", "derived_23", "derived_24", "derived_25", "cc_1", "cc_2", "cc_3",
        "cc_4", "cc_5", "base_time", "length", "shares", "status", "h_local", "sunday_post",
        "monday_post", "tuesday_post", "wednesday_post", "thursday_post", "friday_post",
        "saturday_post", "sunday_base", "monday_base", "tuesday_base", "wednesday_base",
        "thursday_base", "friday_base", "saturday_base"     
    ]
    target = "target"
    
    # MLP is sensitive to feature scaling!
    X = MinMaxScaler().fit_transform(dataframe[features].values)
    y = dataframe[target].values
    
    return X, y


def prepare_for_classification(dataframe):
    """
    Prepare the data for a classification problem where we will attempt
    to predict the category of a Facebook post given features of the data.
    
    Returns a tuple containing an nd array of features (X)
    and a 1d array for the target (y)
    """
    features = [
        "likes", "views", "returns", "derived_1", "derived_2", "derived_3",
        "derived_4", "derived_5", "derived_6", "derived_7", "derived_8", "derived_9",
        "derived_10", "derived_11", "derived_12", "derived_13", "derived_14", "derived_15", 
        "derived_16", "derived_17", "derived_18", "derived_19", "derived_20", "derived_21",
        "derived_22", "derived_23", "derived_24", "derived_25", "cc_1", "cc_2", "cc_3",
        "cc_4", "cc_5", "base_time", "length", "shares", "status", "h_local", "sunday_post",
        "monday_post", "tuesday_post", "wednesday_post", "thursday_post", "friday_post",
        "saturday_post", "sunday_base", "monday_base", "tuesday_base", "wednesday_base",
        "thursday_base", "friday_base", "saturday_base", "target"     
    ]
    target = "category"
    
    # MLP is sensitive to feature scaling!
    X = MinMaxScaler().fit_transform(dataframe[features].values)
    y = dataframe[target].values
    
    return X, y

# %%
# Prepare the data and break in to training and test splits
X, y = prepare_for_regression(data)
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Instantiate the model, set hyperparameters, and train

# %%
model = MLPRegressor(hidden_layer_sizes=(400, 400, 100), verbose=True)
model.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# Iteration 1, loss = 434.76410260
# Iteration 2, loss = 350.77198078
# Iteration 3, loss = 326.75197441
# Iteration 4, loss = 312.67223911
# Iteration 5, loss = 284.86038599
# Iteration 6, loss = 279.27152231
# Iteration 7, loss = 261.81973154
# Iteration 8, loss = 262.41991009
# Iteration 9, loss = 255.90716310
# Iteration 10, loss = 241.76663326
# Iteration 11, loss = 244.92183374
# Iteration 12, loss = 255.10051392
# Iteration 13, loss = 222.85457914
# Iteration 14, loss = 229.59588743
# Iteration 15, loss = 234.65298207
# Iteration 16, loss = 245.18949356
# Iteration 17, loss = 209.36780407
# Iteration 18, loss = 214.67596246
# Iteration 19, loss = 216.47577881
# Iteration 20, loss = 220.56510356
# Iteration 21, loss = 197.94491514
# Iteration 22, loss = 204.90735620
# Iteration 23, loss = 205.66973795
# Iteration 24, loss = 195.66454477
# Iteration 25, loss = 189.24327357
# Iteration 26, loss = 193.94093015
# Iteration 27, loss = 195.91166356
# Iteration 28, loss = 187.63709163
# Iteration 29, loss = 191.16016830
# Iteration 30, loss = 174.57966736
# Iteration 31, loss = 181.79699136
# Iteration 32, loss = 198.54979394
# Iteration 33, loss = 187.61157892
# Iteration 34, loss = 181.04432293
# Iteration 35, loss = 172.15710701
# Iteration 36, loss = 170.18335683
# Iteration 37, loss = 171.91429380
# Iteration 38, loss = 166.64489208
# Iteration 39, loss = 184.87417151
# Iteration 40, loss = 169.22880312
# Iteration 41, loss = 176.34330297
# Iteration 42, loss = 181.47083091
# Iteration 43, loss = 169.57267641
# Iteration 44, loss = 162.47287364
# Iteration 45, loss = 177.09124771
# Iteration 46, loss = 157.13359509
# Iteration 47, loss = 158.50008812
# Iteration 48, loss = 163.05158398
# Iteration 49, loss = 154.19657542
# Iteration 50, loss = 157.41749905
# Iteration 51, loss = 157.49141144
# Iteration 52, loss = 156.66006142
# Iteration 53, loss = 152.99049198
# Iteration 54, loss = 191.07709910
# Iteration 55, loss = 160.30669970
# Iteration 56, loss = 154.73787381
# Iteration 57, loss = 142.47889761
# Iteration 58, loss = 147.81339939
# Iteration 59, loss = 152.14506464
# Iteration 60, loss = 141.15908412
# Iteration 61, loss = 146.75713408
# Iteration 62, loss = 143.60255947
# Iteration 63, loss = 149.66803699
# Iteration 64, loss = 138.42908248
# Iteration 65, loss = 140.89811803
# Iteration 66, loss = 136.42128677
# Iteration 67, loss = 139.11616794
# Iteration 68, loss = 138.35151982
# Iteration 69, loss = 140.99353319
# Iteration 70, loss = 142.87677715
# Iteration 71, loss = 143.15216974
# Iteration 72, loss = 136.00023285
# Iteration 73, loss = 143.38510485
# Iteration 74, loss = 129.66926993
# Iteration 75, loss = 124.53103922
# Iteration 76, loss = 131.93458375
# Iteration 77, loss = 136.39569301
# Iteration 78, loss = 130.51918888
# Iteration 79, loss = 126.40081119
# Iteration 80, loss = 133.11338200
# Iteration 81, loss = 127.81478682
# Iteration 82, loss = 124.91320756
# Iteration 83, loss = 130.84256098
# Iteration 84, loss = 121.16886468
# Iteration 85, loss = 123.49521804
# Iteration 86, loss = 123.02384725
# Iteration 87, loss = 125.50361859
# Iteration 88, loss = 128.42474331
# Iteration 89, loss = 127.13041137
# Iteration 90, loss = 121.43167906
# Iteration 91, loss = 130.48203591
# Iteration 92, loss = 117.29468973
# Iteration 93, loss = 114.74843656
# Iteration 94, loss = 119.74588493
# Iteration 95, loss = 114.07552623
# Iteration 96, loss = 113.03924777
# Iteration 97, loss = 116.62839813
# Iteration 98, loss = 114.39979324
# Iteration 99, loss = 125.05761262
# Iteration 100, loss = 112.22451617
# Iteration 101, loss = 108.23614953
# Iteration 102, loss = 108.07173887
# Iteration 103, loss = 113.84767125
# Iteration 104, loss = 112.95333929
# Iteration 105, loss = 109.32529718
# Iteration 106, loss = 105.76759497
# Iteration 107, loss = 104.88766542
# Iteration 108, loss = 107.83568922
# Iteration 109, loss = 117.86710890
# Iteration 110, loss = 108.81379480
# Iteration 111, loss = 101.36887854
# Iteration 112, loss = 101.74470600
# Iteration 113, loss = 103.41165827
# Iteration 114, loss = 106.13929377
# Iteration 115, loss = 106.69658925
# Iteration 116, loss = 100.74752381
# Iteration 117, loss = 93.66856727
# Iteration 118, loss = 98.92564679
# Iteration 119, loss = 100.94698654
# Iteration 120, loss = 94.98776254
# Iteration 121, loss = 107.35180872
# Iteration 122, loss = 105.09775913
# Iteration 123, loss = 100.99712140
# Iteration 124, loss = 96.12427886
# Iteration 125, loss = 93.54209246
# Iteration 126, loss = 92.08837792
# Iteration 127, loss = 98.36205224
# Iteration 128, loss = 89.05892068
# Iteration 129, loss = 93.79821080
# Iteration 130, loss = 96.06931758
# Iteration 131, loss = 95.79994712
# Iteration 132, loss = 100.56787630
# Iteration 133, loss = 92.65371369
# Iteration 134, loss = 95.71317047
# Iteration 135, loss = 93.21726405
# Iteration 136, loss = 91.93985371
# Iteration 137, loss = 85.11612552
# Iteration 138, loss = 89.87064890
# Iteration 139, loss = 97.39614568
# Iteration 140, loss = 83.25681746
# Iteration 141, loss = 80.42875358
# Iteration 142, loss = 83.41201559
# Iteration 143, loss = 90.89019679
# Iteration 144, loss = 84.39855788
# Iteration 145, loss = 85.77461933
# Iteration 146, loss = 83.86072372
# Iteration 147, loss = 86.59823706
# Iteration 148, loss = 78.03110021
# Iteration 149, loss = 83.09436454
# Iteration 150, loss = 80.09782382
# Iteration 151, loss = 82.62250456
# Iteration 152, loss = 83.83370182
# Iteration 153, loss = 79.78050318
# Iteration 154, loss = 82.46087632
# Iteration 155, loss = 73.92767125
# Iteration 156, loss = 80.26946350
# Iteration 157, loss = 80.43969336
# Iteration 158, loss = 89.25715367
# Iteration 159, loss = 76.44185204
# Iteration 160, loss = 69.81320318
# Iteration 161, loss = 75.44332097
# Iteration 162, loss = 76.19687231
# Iteration 163, loss = 74.33203687
# Iteration 164, loss = 74.31805876
# Iteration 165, loss = 72.04922638
# Iteration 166, loss = 70.61206664
# Iteration 167, loss = 73.71865195
# Iteration 168, loss = 73.49905109
# Iteration 169, loss = 66.83062260
# Iteration 170, loss = 74.99572711
# Iteration 171, loss = 69.02926113
# Iteration 172, loss = 69.88072996
# Iteration 173, loss = 73.10539662
# Iteration 174, loss = 72.07223640
# Iteration 175, loss = 73.64548912
# Iteration 176, loss = 75.18346196
# Iteration 177, loss = 70.70028126
# Iteration 178, loss = 65.79378231
# Iteration 179, loss = 66.72478963
# Iteration 180, loss = 63.54336874
# Iteration 181, loss = 60.79803662
# Iteration 182, loss = 70.26195910
# Iteration 183, loss = 60.80289273
# Iteration 184, loss = 80.16035039
# Iteration 185, loss = 67.01804788
# Iteration 186, loss = 64.92807560
# Iteration 187, loss = 64.42590696
# Iteration 188, loss = 63.24378207
# Iteration 189, loss = 54.96756850
# Iteration 190, loss = 57.31929559
# Iteration 191, loss = 58.66338928
# Iteration 192, loss = 71.81157850
# Iteration 193, loss = 65.15296831
# Iteration 194, loss = 59.66197236
# Iteration 195, loss = 61.67370710
# Iteration 196, loss = 65.20960694
# Iteration 197, loss = 54.07965616
# Iteration 198, loss = 56.04034659
# Iteration 199, loss = 63.53035305
# Iteration 200, loss = 56.53101215
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
r2 = r2_score(y_test, pred)
mse = mean_squared_error(y_test, pred)

print("Coefficient of determination: {}".format(r2))
print("Error: {}".format(mse))
# Out:
# Coefficient of determination: 0.6017433262854475
# Error: 523.3410162385932

# %% [markdown]
# ## Visualize the results using Yellowbrick

# %%
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()

# %%
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()

# %% [markdown]
# ## Tune the hyperparameters

# %% [markdown]
# ## Pickle the model

# %% [markdown]
# ## Restore the model and run live predictions

# %% [markdown]
# ## Takeaways from our scikit-learn prototype:
#     - sklearn API is convenient
#     - can tune some hyperparams
#     - tough to tune for overfit model... would be nice to have dropout, for instance
#     - sloooooow
